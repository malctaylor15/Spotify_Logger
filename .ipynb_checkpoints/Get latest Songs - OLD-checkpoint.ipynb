# %%
import os 
import sys 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import re
import pickle
import json
import sqlite3
from pprint import pprint
import datetime
from tqdm.notebook import tqdm
tqdm.pandas()
# Out:
# /Users/malcolmtaylor/Github_Projects/venv/lib/python3.8/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

# %%
# %load_ext autoreload
# %autoreload 2

# %%
with open('data/spotify_creds.pkl', 'rb') as hnd:
    credentials = pickle.load(hnd)

# %%
os.environ.update(credentials)

# %%
scope = "user-read-recently-played"

# %%
os.environ['SPOTIPY_REDIRECT_URI'] = 'https://malcolm-taylor.info/'
spotify = spotipy.Spotify(client_credentials_manager= SpotifyOAuth(scope=scope
                                                                   , username='malchemist02'))

# %% [raw]
# spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials() )

# %%
def get_recently_played(before=None):
    recently_played = spotify.current_user_recently_played(before)
    print('Getting songs at ', datetime.datetime.now())
    before = recently_played['cursors']['before']
    print('Latest song in spotify pull started at ', datetime.datetime.fromtimestamp(int(before)/1000))
    after = recently_played['cursors']['after']
    print('Earliest song in spotify pull started at ', datetime.datetime.fromtimestamp(int(after)/1000))

# %%
recently_played = spotify.current_user_recently_played()
print(datetime.datetime.now())
# Out:
# 2020-07-31 21:29:29.218052

# %%
recene

# %%
recently_played.keys()
# Out:
# dict_keys(['items', 'next', 'cursors', 'limit', 'href'])

# %%
recently_played.keys()
# Out:
# dict_keys(['items', 'next', 'cursors', 'limit', 'href'])

# %%
recently_played
# Out:
# {'items': [{'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#        'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#        'id': '5M52tdBnJaKSvOpJGz8mfZ',
#        'name': 'Black Sabbath',
#        'type': 'artist',
#        'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6r7LZXAVueS5DqdrvXJJK7'},
#      'href': 'https://api.spotify.com/v1/albums/6r7LZXAVueS5DqdrvXJJK7',
#      'id': '6r7LZXAVueS5DqdrvXJJK7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27382fd952c052899397f8c9917',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0282fd952c052899397f8c9917',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485182fd952c052899397f8c9917',
#        'width': 64}],
#      'name': 'Paranoid (2014 Remaster)',
#      'release_date': '1970-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:6r7LZXAVueS5DqdrvXJJK7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 168405,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11304628'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Y373MqadDRtclJNdnUXVc'},
#     'href': 'https://api.spotify.com/v1/tracks/1Y373MqadDRtclJNdnUXVc',
#     'id': '1Y373MqadDRtclJNdnUXVc',
#     'is_local': False,
#     'name': 'Paranoid - 2016 Remaster',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/08232f9feba37a3acbb31062bc9e99dac9c7e262?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1Y373MqadDRtclJNdnUXVc'},
#    'played_at': '2020-08-01T01:25:40.275Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ/recommended'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ:recommended',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ:recommended'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvRX0y0JYtGOmGJwLwyIL'},
#        'href': 'https://api.spotify.com/v1/artists/5zvRX0y0JYtGOmGJwLwyIL',
#        'id': '5zvRX0y0JYtGOmGJwLwyIL',
#        'name': 'Bachata Heightz',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zvRX0y0JYtGOmGJwLwyIL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DelqlcfTa9sEm4BL5Jjtf'},
#      'href': 'https://api.spotify.com/v1/albums/0DelqlcfTa9sEm4BL5Jjtf',
#      'id': '0DelqlcfTa9sEm4BL5Jjtf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e76f5eda4b29c17476420a7a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e76f5eda4b29c17476420a7a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e76f5eda4b29c17476420a7a',
#        'width': 64}],
#      'name': 'Lost in the Music',
#      'release_date': '2019-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0DelqlcfTa9sEm4BL5Jjtf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvRX0y0JYtGOmGJwLwyIL'},
#       'href': 'https://api.spotify.com/v1/artists/5zvRX0y0JYtGOmGJwLwyIL',
#       'id': '5zvRX0y0JYtGOmGJwLwyIL',
#       'name': 'Bachata Heightz',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zvRX0y0JYtGOmGJwLwyIL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7h9r1hKkJ7FGA6k5vjiz1i'},
#       'href': 'https://api.spotify.com/v1/artists/7h9r1hKkJ7FGA6k5vjiz1i',
#       'id': '7h9r1hKkJ7FGA6k5vjiz1i',
#       'name': 'Circharles',
#       'type': 'artist',
#       'uri': 'spotify:artist:7h9r1hKkJ7FGA6k5vjiz1i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 250000,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADX1860100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6R8Wtmkt4gExspMQV3W9xw'},
#     'href': 'https://api.spotify.com/v1/tracks/6R8Wtmkt4gExspMQV3W9xw',
#     'id': '6R8Wtmkt4gExspMQV3W9xw',
#     'is_local': False,
#     'name': 'Era Mentira',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/903bf3709f7ba9010f51a7ab8374b16859000b3e?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6R8Wtmkt4gExspMQV3W9xw'},
#    'played_at': '2020-08-01T01:22:51.918Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ/recommended'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ:recommended',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ:recommended'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#        'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#        'id': '6eJa3zG1QZLRB3xgRuyxbm',
#        'name': 'Dayglow',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PFzbdbZRNaoGLCHFPnmv3'},
#      'href': 'https://api.spotify.com/v1/albums/5PFzbdbZRNaoGLCHFPnmv3',
#      'id': '5PFzbdbZRNaoGLCHFPnmv3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ccd63af052f7e438c05f6c94',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ccd63af052f7e438c05f6c94',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ccd63af052f7e438c05f6c94',
#        'width': 64}],
#      'name': 'Fuzzybrain',
#      'release_date': '2019-11-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5PFzbdbZRNaoGLCHFPnmv3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#       'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#       'id': '6eJa3zG1QZLRB3xgRuyxbm',
#       'name': 'Dayglow',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 278769,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADL1825079'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64lsIF5pw0sJY0gV5kz0RN'},
#     'href': 'https://api.spotify.com/v1/tracks/64lsIF5pw0sJY0gV5kz0RN',
#     'id': '64lsIF5pw0sJY0gV5kz0RN',
#     'is_local': False,
#     'name': 'Can I Call You Tonight?',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1df9f9b1d2fa409883d304d9fd3b8e45110e72fc?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:64lsIF5pw0sJY0gV5kz0RN'},
#    'played_at': '2020-08-01T01:18:41.859Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ/recommended'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ:recommended',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ:recommended'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#        'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#        'id': '6eJa3zG1QZLRB3xgRuyxbm',
#        'name': 'Dayglow',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PFzbdbZRNaoGLCHFPnmv3'},
#      'href': 'https://api.spotify.com/v1/albums/5PFzbdbZRNaoGLCHFPnmv3',
#      'id': '5PFzbdbZRNaoGLCHFPnmv3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ccd63af052f7e438c05f6c94',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ccd63af052f7e438c05f6c94',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ccd63af052f7e438c05f6c94',
#        'width': 64}],
#      'name': 'Fuzzybrain',
#      'release_date': '2019-11-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5PFzbdbZRNaoGLCHFPnmv3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#       'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#       'id': '6eJa3zG1QZLRB3xgRuyxbm',
#       'name': 'Dayglow',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 278769,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADL1825079'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64lsIF5pw0sJY0gV5kz0RN'},
#     'href': 'https://api.spotify.com/v1/tracks/64lsIF5pw0sJY0gV5kz0RN',
#     'id': '64lsIF5pw0sJY0gV5kz0RN',
#     'is_local': False,
#     'name': 'Can I Call You Tonight?',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1df9f9b1d2fa409883d304d9fd3b8e45110e72fc?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:64lsIF5pw0sJY0gV5kz0RN'},
#    'played_at': '2020-08-01T01:14:02.299Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ/recommended'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ:recommended',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ:recommended'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#        'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#        'id': '50JJSqHUf2RQ9xsHs0KMHg',
#        'name': 'Jon Bellion',
#        'type': 'artist',
#        'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59YYObx9wFEFG5zVdlfwvf'},
#      'href': 'https://api.spotify.com/v1/albums/59YYObx9wFEFG5zVdlfwvf',
#      'id': '59YYObx9wFEFG5zVdlfwvf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc200956ba9de7303d8bd068',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc200956ba9de7303d8bd068',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc200956ba9de7303d8bd068',
#        'width': 64}],
#      'name': 'Glory Sound Prep',
#      'release_date': '2018-11-09',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:59YYObx9wFEFG5zVdlfwvf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#       'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#       'id': '50JJSqHUf2RQ9xsHs0KMHg',
#       'name': 'Jon Bellion',
#       'type': 'artist',
#       'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 183344,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71817097'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FUDWkguOUVpLRAVn5C20z'},
#     'href': 'https://api.spotify.com/v1/tracks/4FUDWkguOUVpLRAVn5C20z',
#     'id': '4FUDWkguOUVpLRAVn5C20z',
#     'is_local': False,
#     'name': 'Blu',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cb9e82a04f2e773bc80921fd8a03ab469c4d07e5?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4FUDWkguOUVpLRAVn5C20z'},
#    'played_at': '2020-08-01T00:50:24.290Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jTnHxhb6cDCaCu4rdvsQ0'},
#        'href': 'https://api.spotify.com/v1/artists/6jTnHxhb6cDCaCu4rdvsQ0',
#        'id': '6jTnHxhb6cDCaCu4rdvsQ0',
#        'name': 'Hot Chelle Rae',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jTnHxhb6cDCaCu4rdvsQ0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yEOTb4pxjD0VbEVs0Ni9d'},
#      'href': 'https://api.spotify.com/v1/albums/2yEOTb4pxjD0VbEVs0Ni9d',
#      'id': '2yEOTb4pxjD0VbEVs0Ni9d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27352e006512263716212f98634',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0252e006512263716212f98634',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152e006512263716212f98634',
#        'width': 64}],
#      'name': 'Tomorrow Me',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2yEOTb4pxjD0VbEVs0Ni9d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jTnHxhb6cDCaCu4rdvsQ0'},
#       'href': 'https://api.spotify.com/v1/artists/6jTnHxhb6cDCaCu4rdvsQ0',
#       'id': '6jTnHxhb6cDCaCu4rdvsQ0',
#       'name': 'Hot Chelle Rae',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jTnHxhb6cDCaCu4rdvsQ0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 168000,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4TW2079109'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JLL4gFHNCZGhfgrhRIIxb'},
#     'href': 'https://api.spotify.com/v1/tracks/4JLL4gFHNCZGhfgrhRIIxb',
#     'id': '4JLL4gFHNCZGhfgrhRIIxb',
#     'is_local': False,
#     'name': 'Tomorrow Me',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/29423ea444ac55f5910841e1e290c4475fc261f0?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4JLL4gFHNCZGhfgrhRIIxb'},
#    'played_at': '2020-08-01T00:42:43.012Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ApUX1o6oSz321MMECyIYd'},
#        'href': 'https://api.spotify.com/v1/artists/3ApUX1o6oSz321MMECyIYd',
#        'id': '3ApUX1o6oSz321MMECyIYd',
#        'name': 'Quinn XCII',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ApUX1o6oSz321MMECyIYd'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Rp02sRtYz5Kp9qHP4VcxQ'},
#      'href': 'https://api.spotify.com/v1/albums/4Rp02sRtYz5Kp9qHP4VcxQ',
#      'id': '4Rp02sRtYz5Kp9qHP4VcxQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738fbcfc1032701d6703f10391',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028fbcfc1032701d6703f10391',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518fbcfc1032701d6703f10391',
#        'width': 64}],
#      'name': 'Change of Scenery',
#      'release_date': '2015-04-28',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:4Rp02sRtYz5Kp9qHP4VcxQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ApUX1o6oSz321MMECyIYd'},
#       'href': 'https://api.spotify.com/v1/artists/3ApUX1o6oSz321MMECyIYd',
#       'id': '3ApUX1o6oSz321MMECyIYd',
#       'name': 'Quinn XCII',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ApUX1o6oSz321MMECyIYd'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 255000,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm21578602'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4gHSezW5CHZCvjAUjF2pd5'},
#     'href': 'https://api.spotify.com/v1/tracks/4gHSezW5CHZCvjAUjF2pd5',
#     'id': '4gHSezW5CHZCvjAUjF2pd5',
#     'is_local': False,
#     'name': 'Another Day in Paradise',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ce833a248e413298c838f3f0ea3d4d49f3397af3?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4gHSezW5CHZCvjAUjF2pd5'},
#    'played_at': '2020-08-01T00:39:54.974Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ShZZUjkbXCjhwrb18BA8I'},
#        'href': 'https://api.spotify.com/v1/artists/1ShZZUjkbXCjhwrb18BA8I',
#        'id': '1ShZZUjkbXCjhwrb18BA8I',
#        'name': 'Bryce Vine',
#        'type': 'artist',
#        'uri': 'spotify:artist:1ShZZUjkbXCjhwrb18BA8I'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/08IW6sUfN9fRYG8Xlgm4oC'},
#      'href': 'https://api.spotify.com/v1/albums/08IW6sUfN9fRYG8Xlgm4oC',
#      'id': '08IW6sUfN9fRYG8Xlgm4oC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d67c496c586f830b6a73ea8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d67c496c586f830b6a73ea8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d67c496c586f830b6a73ea8c',
#        'width': 64}],
#      'name': 'Lazy Fair',
#      'release_date': '2014-04-22',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:08IW6sUfN9fRYG8Xlgm4oC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ShZZUjkbXCjhwrb18BA8I'},
#       'href': 'https://api.spotify.com/v1/artists/1ShZZUjkbXCjhwrb18BA8I',
#       'id': '1ShZZUjkbXCjhwrb18BA8I',
#       'name': 'Bryce Vine',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ShZZUjkbXCjhwrb18BA8I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 252546,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQY51460659'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5DJNyvuMmZfsfvdTpMMmUq'},
#     'href': 'https://api.spotify.com/v1/tracks/5DJNyvuMmZfsfvdTpMMmUq',
#     'id': '5DJNyvuMmZfsfvdTpMMmUq',
#     'is_local': False,
#     'name': 'Sour Patch Kids',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4cc2a549916e40f7552882f5c202eeae13d43054?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5DJNyvuMmZfsfvdTpMMmUq'},
#    'played_at': '2020-08-01T00:35:39.988Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0imE3buPhAowREqCrr4CYe'},
#        'href': 'https://api.spotify.com/v1/artists/0imE3buPhAowREqCrr4CYe',
#        'id': '0imE3buPhAowREqCrr4CYe',
#        'name': 'Peach Tree Rascals',
#        'type': 'artist',
#        'uri': 'spotify:artist:0imE3buPhAowREqCrr4CYe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0vpGo2ef7QNOKQHtd7qZeh'},
#      'href': 'https://api.spotify.com/v1/albums/0vpGo2ef7QNOKQHtd7qZeh',
#      'id': '0vpGo2ef7QNOKQHtd7qZeh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273edbe76ceedb13cd7f6bc874d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02edbe76ceedb13cd7f6bc874d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851edbe76ceedb13cd7f6bc874d',
#        'width': 64}],
#      'name': 'Mariposa',
#      'release_date': '2019-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0vpGo2ef7QNOKQHtd7qZeh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0imE3buPhAowREqCrr4CYe'},
#       'href': 'https://api.spotify.com/v1/artists/0imE3buPhAowREqCrr4CYe',
#       'id': '0imE3buPhAowREqCrr4CYe',
#       'name': 'Peach Tree Rascals',
#       'type': 'artist',
#       'uri': 'spotify:artist:0imE3buPhAowREqCrr4CYe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 210000,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZFZ21934119'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ja2gzrNh9VNigzoXfmbwD'},
#     'href': 'https://api.spotify.com/v1/tracks/4ja2gzrNh9VNigzoXfmbwD',
#     'id': '4ja2gzrNh9VNigzoXfmbwD',
#     'is_local': False,
#     'name': 'Mariposa',
#     'popularity': 86,
#     'preview_url': 'https://p.scdn.co/mp3-preview/626f2eb20b33206e8caeb46b42d00a31416a61b8?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ja2gzrNh9VNigzoXfmbwD'},
#    'played_at': '2020-08-01T00:31:27.463Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#        'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#        'id': '7wg1qvie3KqDNQbAkTdbX0',
#        'name': 'Louis The Child',
#        'type': 'artist',
#        'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4aBLjtEUUg1424XB5WQgKP'},
#      'href': 'https://api.spotify.com/v1/albums/4aBLjtEUUg1424XB5WQgKP',
#      'id': '4aBLjtEUUg1424XB5WQgKP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d0c97444ecc52c4ca601144a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d0c97444ecc52c4ca601144a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d0c97444ecc52c4ca601144a',
#        'width': 64}],
#      'name': 'Here For Now',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4aBLjtEUUg1424XB5WQgKP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#       'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#       'id': '7wg1qvie3KqDNQbAkTdbX0',
#       'name': 'Louis The Child',
#       'type': 'artist',
#       'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ApUX1o6oSz321MMECyIYd'},
#       'href': 'https://api.spotify.com/v1/artists/3ApUX1o6oSz321MMECyIYd',
#       'id': '3ApUX1o6oSz321MMECyIYd',
#       'name': 'Quinn XCII',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ApUX1o6oSz321MMECyIYd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#       'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#       'id': '5JMLG56F1X5mFmWNmS0iAp',
#       'name': 'Chelsea Cutler',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72006496'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/52681Ivj8kgCi90Lu8B9fl'},
#     'href': 'https://api.spotify.com/v1/tracks/52681Ivj8kgCi90Lu8B9fl',
#     'id': '52681Ivj8kgCi90Lu8B9fl',
#     'is_local': False,
#     'name': 'Little Things (with Quinn XCII & Chelsea Cutler)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e2701bc924cd2d91634de9979288274247dd4dd3?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:52681Ivj8kgCi90Lu8B9fl'},
#    'played_at': '2020-08-01T00:27:57.489Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#        'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#        'id': '7wg1qvie3KqDNQbAkTdbX0',
#        'name': 'Louis The Child',
#        'type': 'artist',
#        'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4aBLjtEUUg1424XB5WQgKP'},
#      'href': 'https://api.spotify.com/v1/albums/4aBLjtEUUg1424XB5WQgKP',
#      'id': '4aBLjtEUUg1424XB5WQgKP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d0c97444ecc52c4ca601144a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d0c97444ecc52c4ca601144a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d0c97444ecc52c4ca601144a',
#        'width': 64}],
#      'name': 'Here For Now',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4aBLjtEUUg1424XB5WQgKP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#       'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#       'id': '7wg1qvie3KqDNQbAkTdbX0',
#       'name': 'Louis The Child',
#       'type': 'artist',
#       'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ApUX1o6oSz321MMECyIYd'},
#       'href': 'https://api.spotify.com/v1/artists/3ApUX1o6oSz321MMECyIYd',
#       'id': '3ApUX1o6oSz321MMECyIYd',
#       'name': 'Quinn XCII',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ApUX1o6oSz321MMECyIYd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#       'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#       'id': '5JMLG56F1X5mFmWNmS0iAp',
#       'name': 'Chelsea Cutler',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72006496'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/52681Ivj8kgCi90Lu8B9fl'},
#     'href': 'https://api.spotify.com/v1/tracks/52681Ivj8kgCi90Lu8B9fl',
#     'id': '52681Ivj8kgCi90Lu8B9fl',
#     'is_local': False,
#     'name': 'Little Things (with Quinn XCII & Chelsea Cutler)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e2701bc924cd2d91634de9979288274247dd4dd3?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:52681Ivj8kgCi90Lu8B9fl'},
#    'played_at': '2020-08-01T00:24:40.006Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AP3UU4TfEmHcWWw0LVlOZ'},
#     'href': 'https://api.spotify.com/v1/playlists/2AP3UU4TfEmHcWWw0LVlOZ',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AP3UU4TfEmHcWWw0LVlOZ'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#        'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
# ...
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 159124,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32000701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7tDHMhO0bJpbkXzMyMIE0b'},
#     'href': 'https://api.spotify.com/v1/tracks/7tDHMhO0bJpbkXzMyMIE0b',
#     'id': '7tDHMhO0bJpbkXzMyMIE0b',
#     'is_local': False,
#     'name': 'Isla De Flores',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/30647ec7feb19d8629bb6682e2c86c07ae69ebb6?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7tDHMhO0bJpbkXzMyMIE0b'},
#    'played_at': '2020-07-31T06:21:35.234Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CUZliHXKYjXEV2BOZqMvi'},
#        'href': 'https://api.spotify.com/v1/artists/2CUZliHXKYjXEV2BOZqMvi',
#        'id': '2CUZliHXKYjXEV2BOZqMvi',
#        'name': 'Tosh Møller',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CUZliHXKYjXEV2BOZqMvi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5uwhCxqzuBqaaMqg8IcHa6'},
#      'href': 'https://api.spotify.com/v1/albums/5uwhCxqzuBqaaMqg8IcHa6',
#      'id': '5uwhCxqzuBqaaMqg8IcHa6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738aac0d0c263549c191fbe582',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028aac0d0c263549c191fbe582',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518aac0d0c263549c191fbe582',
#        'width': 64}],
#      'name': 'Alene uden dig',
#      'release_date': '2019-11-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5uwhCxqzuBqaaMqg8IcHa6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CUZliHXKYjXEV2BOZqMvi'},
#       'href': 'https://api.spotify.com/v1/artists/2CUZliHXKYjXEV2BOZqMvi',
#       'id': '2CUZliHXKYjXEV2BOZqMvi',
#       'name': 'Tosh Møller',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CUZliHXKYjXEV2BOZqMvi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 157500,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W31916502'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3eMTcFDfBkdUxzRDAb8Krs'},
#     'href': 'https://api.spotify.com/v1/tracks/3eMTcFDfBkdUxzRDAb8Krs',
#     'id': '3eMTcFDfBkdUxzRDAb8Krs',
#     'is_local': False,
#     'name': 'Alene uden dig',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/411acbc29f006d3276a842c9a84ecf543616231d?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3eMTcFDfBkdUxzRDAb8Krs'},
#    'played_at': '2020-07-31T05:49:40.238Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27DGFhdWUeudNFbPJROkWF'},
#        'href': 'https://api.spotify.com/v1/artists/27DGFhdWUeudNFbPJROkWF',
#        'id': '27DGFhdWUeudNFbPJROkWF',
#        'name': 'Comet Blue',
#        'type': 'artist',
#        'uri': 'spotify:artist:27DGFhdWUeudNFbPJROkWF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6YF5cIpHznEz9HTrLAOLwf'},
#      'href': 'https://api.spotify.com/v1/albums/6YF5cIpHznEz9HTrLAOLwf',
#      'id': '6YF5cIpHznEz9HTrLAOLwf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737b854b8462b0012ee59724cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027b854b8462b0012ee59724cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517b854b8462b0012ee59724cd',
#        'width': 64}],
#      'name': 'Sand Between Our Fingers',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6YF5cIpHznEz9HTrLAOLwf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27DGFhdWUeudNFbPJROkWF'},
#       'href': 'https://api.spotify.com/v1/artists/27DGFhdWUeudNFbPJROkWF',
#       'id': '27DGFhdWUeudNFbPJROkWF',
#       'name': 'Comet Blue',
#       'type': 'artist',
#       'uri': 'spotify:artist:27DGFhdWUeudNFbPJROkWF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 168125,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6N22021887'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/55S0Xumnc0oNtM3fzh2Oex'},
#     'href': 'https://api.spotify.com/v1/tracks/55S0Xumnc0oNtM3fzh2Oex',
#     'id': '55S0Xumnc0oNtM3fzh2Oex',
#     'is_local': False,
#     'name': 'Sand Between Our Fingers',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f814ab7228958c339bb801cd1879881ceeb2f446?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:55S0Xumnc0oNtM3fzh2Oex'},
#    'played_at': '2020-07-31T05:47:02.750Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KnoW7Kuw3lj3OKFK8EXQ7'},
#        'href': 'https://api.spotify.com/v1/artists/2KnoW7Kuw3lj3OKFK8EXQ7',
#        'id': '2KnoW7Kuw3lj3OKFK8EXQ7',
#        'name': 'Eric Badanti',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KnoW7Kuw3lj3OKFK8EXQ7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3q10Tg3kwZZmQYCLaCZos7'},
#      'href': 'https://api.spotify.com/v1/albums/3q10Tg3kwZZmQYCLaCZos7',
#      'id': '3q10Tg3kwZZmQYCLaCZos7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bea1dd3632fa82a869a1ea31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bea1dd3632fa82a869a1ea31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bea1dd3632fa82a869a1ea31',
#        'width': 64}],
#      'name': 'Vals De Rodrigues',
#      'release_date': '2019-09-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3q10Tg3kwZZmQYCLaCZos7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KnoW7Kuw3lj3OKFK8EXQ7'},
#       'href': 'https://api.spotify.com/v1/artists/2KnoW7Kuw3lj3OKFK8EXQ7',
#       'id': '2KnoW7Kuw3lj3OKFK8EXQ7',
#       'name': 'Eric Badanti',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KnoW7Kuw3lj3OKFK8EXQ7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161209,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF1905801'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3I3WY0C7AQMe6Z6hMUQqd5'},
#     'href': 'https://api.spotify.com/v1/tracks/3I3WY0C7AQMe6Z6hMUQqd5',
#     'id': '3I3WY0C7AQMe6Z6hMUQqd5',
#     'is_local': False,
#     'name': 'Vals De Rodrigues',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a274dc8f39ed08d7acc834d20ebab21e78d89755?cid=fe68e6aabfa54dc7a1afee177328ea22',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3I3WY0C7AQMe6Z6hMUQqd5'},
#    'played_at': '2020-07-31T05:44:14.645Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'}}],
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?before=1596174254645&limit=50',
#  'cursors': {'after': '1596245140275', 'before': '1596174254645'},
#  'limit': 50,
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?limit=50'}

# %%
len(recently_played['items'])
# Out:
# 50

# %%
recently_played['items'][0].keys()
# Out:
# dict_keys(['track', 'played_at', 'context'])

# %%
(recently_played['items'][0]['played_at'])
# Out:
# '2020-08-01T01:25:40.275Z'

# %%
recently_played['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
track_keep_keys = ['name', 'artists', 'duration_ms', 'popularity', 'uri', 'id']

# %%
recently_played['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#     'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#     'id': '5M52tdBnJaKSvOpJGz8mfZ',
#     'name': 'Black Sabbath',
#     'type': 'artist',
#     'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#   'available_markets': ['CA', 'US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6r7LZXAVueS5DqdrvXJJK7'},
#   'href': 'https://api.spotify.com/v1/albums/6r7LZXAVueS5DqdrvXJJK7',
#   'id': '6r7LZXAVueS5DqdrvXJJK7',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27382fd952c052899397f8c9917',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0282fd952c052899397f8c9917',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485182fd952c052899397f8c9917',
#     'width': 64}],
#   'name': 'Paranoid (2014 Remaster)',
#   'release_date': '1970-09-18',
#   'release_date_precision': 'day',
#   'total_tracks': 8,
#   'type': 'album',
#   'uri': 'spotify:album:6r7LZXAVueS5DqdrvXJJK7'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#    'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#    'id': '5M52tdBnJaKSvOpJGz8mfZ',
#    'name': 'Black Sabbath',
#    'type': 'artist',
#    'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#  'available_markets': ['CA', 'US'],
#  'disc_number': 1,
#  'duration_ms': 168405,
#  'explicit': False,
#  'external_ids': {'isrc': 'USWB11304628'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1Y373MqadDRtclJNdnUXVc'},
#  'href': 'https://api.spotify.com/v1/tracks/1Y373MqadDRtclJNdnUXVc',
#  'id': '1Y373MqadDRtclJNdnUXVc',
#  'is_local': False,
#  'name': 'Paranoid - 2016 Remaster',
#  'popularity': 69,
#  'preview_url': 'https://p.scdn.co/mp3-preview/08232f9feba37a3acbb31062bc9e99dac9c7e262?cid=fe68e6aabfa54dc7a1afee177328ea22',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:1Y373MqadDRtclJNdnUXVc'}

# %%
recently_played = spotify.current_user_recently_played()

# %%
recently_played['items'][-1]['played_at']
# Out:
# '2020-07-31T05:44:14.645Z'

# %%
before = recently_played['cursors']['before']
print('before', before, datetime.datetime.fromtimestamp(int(before)/1000))
after = recently_played['cursors']['after']
print('after', after, datetime.datetime.fromtimestamp(int(after)/1000))
# Out:
# before 1596174254645 2020-07-31 01:44:14.645000
# after 1596245140275 2020-07-31 21:25:40.275000

# %%
recently_played['next']
# Out:
# 'https://api.spotify.com/v1/me/player/recently-played?before=1596174254645&limit=50'

# %%
recently_played = spotify.current_user_recently_played(before = before)

# %%
recently_played['items']
# Out:
# []

# %%
playlists = spotify.user_playlists('malchemist02')
playlists

# %%
len(playlists)

# %%
names = [x['name'] for x in playlists['items']]
names

# %%
def get_playlist_audio_feats(inp_name, playlists):
    pl_names = [x['name'] for x in playlists['items']]
    one_pl = [x for x in playlists['items'] if x['name'].lower() == inp_name.lower()]
    if len(one_pl) != 1:
        print(f"There are {len(one_pl)} playlists found")
        print(one_pl)
        print('Try again')
        return()
    playlist_uri = one_pl[0]['uri']
    tracks = spotify.playlist_tracks(playlist_uri)
    print(f"There are {len(tracks['items'])} songs in the playlist {inp_name}")
    uris = [x['track']['uri'] for x in tracks['items']]
    song_names = [x['track']['name'] for x in tracks['items']]
    track_audio_feats = spotify.audio_features(uris)
    pd_tracks = pd.DataFrame(track_audio_feats, index=song_names)
    pd_tracks['duration_s'] = pd_tracks['duration_ms']/1000.0
    pd_tracks = pd_tracks.drop(['duration_ms'], axis=1)
    return(pd_tracks)

# %% [raw]
# inp_name='Malcolm Bachata'; playlists=playlists
#
# pl_names = [x['name'] for x in playlists['items']]
# one_pl = [x for x in playlists['items'] if x['name'].lower() == inp_name.lower()]
# if len(one_pl) != 1:
#     print(f"There are {len(one_pl)} playlists found")
#     print(one_pl)
#     print('Try again')
#
# playlist_uri = one_pl[0]['uri']
# tracks = spotify.playlist_tracks(playlist_uri)
# print(f"There are {len(tracks['items'])} songs in the playlist {inp_name}")
# uris = [x['track']['uri'] for x in tracks['items']]
# track_audio_feats = spotify.audio_features(uris)
# pd_tracks = pd.DataFrame(track_audio_feats)
# pd_tracks['duration_s'] = pd_tracks['duration_ms']/1000.0
# pd_tracks = pd_tracks.drop(['duration_ms'], axis=1)

# %%
name1 = 'Malcolm Bachata'
playlist1 = get_playlist_audio_feats(name1, playlists)
name2 = 'malcolm salsa'
playlist2 = get_playlist_audio_feats(name2, playlists)

# %%
playlist1.mean()

# %%
playlist2.mean()

# %%
(playlist1.mean() - playlist2.mean()).sort_values()

# %% [markdown]
# ## Segmentation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.tree import export_text
import matplotlib.pyplot as plt 
import graphviz

# %%
### df1 = playlist1.copy()
df1['target'] = 'slow_salsa'
df2 = playlist2.copy()
df2['target'] = 'marc anthony'
df_total = pd.concat([df1, df2])
df_total = df_total[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_s', 'target']]
df_total.shape

# %%
df_total.columns

# %%
dt = DecisionTreeClassifier(max_depth=2)

# %%
X = df_total.copy()
X = X.drop(['target'], axis=1)
y = df_total['target']

# %%
dt.fit(X, y)

# %%
tree.plot_tree(dt
               , feature_names=list(X.columns)
               , class_names=list(y.unique()))

# %% [raw]
# dot_data = tree.export_graphviz(dt, out_file=None,
#                       feature_names=list(X.columns),
#                       class_names=list(y.unique()),
#                       filled=True, rounded=True,
#                       special_characters=True)
# graph = graphviz.Source(dot_data)
# graph

# %%
r = export_text(dt, feature_names=list(X.columns))
print(r)

# %% [markdown]
# ## Graveyard

# %% [raw]
# def view_spot_json(spot_dict):
#     dict1 = spot_dict.copy()
#     drop_keys = ['available_markets']
#     for k, v in dict1.items():
#         for drop_key in drop_keys:
#             if drop_key in dict1.keys():
#                 del(dict1[drop_key])
#                 print("dropped key: "+ drop_key)
#         if type(v) == dict:
#             dict1[k] = view_spot_json(v)
#         if type(v) == list:
#             print(k)
#             cleaned_list = [view_spot_json(x) if type(x) == dict else x for x in v]
#             dict1[k] = cleaned_list
#     return(dict1)

# %% [raw]
# view_spot_json(recently_played)
